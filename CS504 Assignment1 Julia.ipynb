# %%
# Implementation of the equation
function singlefunction(n)
    a = 1
    for i = 1:n
        a = a*((366-n)/365)
    end
    1-a
end
# Out:
# singlefunction (generic function with 1 method)

# %%
function repeatedfunction(i)
    A = [ ]
    for n = 1:i
        append!(A,singlefunction(n))
    end
    A
end
# Out:
# repeatedfunction (generic function with 1 method)

# %%
#Running Result
repeatedfunction(100)
# Out:
# 100-element Array{Any,1}:
#  0.0
#  0.005471945956089352
#  0.01634844749715303
#  0.03247359941765393
#  0.05360663417458711
#  0.079427880128355
#  0.10954682073108024
#  0.14351197056279674
#  0.18082221765508544
#  0.22093923110638725
#  0.2633005008707142
#  0.30733256405282494
#  0.35246397924073924
#  ⋮
#  0.9999999999782913
#  0.9999999999881024
#  0.9999999999935342
#  0.9999999999965158
#  0.9999999999981384
#  0.9999999999990138
#  0.9999999999994821
#  0.9999999999997303
#  0.9999999999998608
#  0.9999999999999288
#  0.9999999999999639
#  0.9999999999999819

# %%
#Plot
using Plots
plot(repeatedfunction(100),xticks = 0:5:100, yticks = 1:0.1:1)
